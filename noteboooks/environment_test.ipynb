# %% [markdown]
# ### Environment Test
#
# Here, we're going to check on those imported packages if they're already been working.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests as req

print("✅ All packages imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"Requests version: {req.__version__}")

# Create a simple plot to test matplotlib
plt.figure(figsize=(8, 4))
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, 'b-', linewidth=2)
plt.title('Test Plot - Environment Working!')
plt.grid(True)
plt.show()

print("🎉 Your Python environment is ready for data analysis!")
# Out:
# ✅ All packages imported successfully!
# Pandas version: 2.2.3
# NumPy version: 2.2.6
# 🎉 Your Python environment is ready for data analysis!
